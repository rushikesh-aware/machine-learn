# %% [markdown]
# <a href="https://colab.research.google.com/github/rushikesh-aware/machine-learn/blob/master/PiechartAssignment2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
 import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
 from google.colab import files
uploaded = files.upload()
df = pd.read_csv("computer_parts.csv")
df
# Out:
#      <input type="file" id="files-a7c055b4-4bcd-42b6-9fa4-1c5d23142f13" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7c055b4-4bcd-42b6-9fa4-1c5d23142f13">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving computer_parts.csv to computer_parts.csv
#           Date;    Product Name;  Number Of Bugs
# 0   08/01/2015;   Arista Router;              10
# 1   09/10/2015;   Arista Router;               3
# 2   09/10/2015;   Arista Router;               6
# 3   10/23/2015;   Arista Router;               8
# 4   10/23/2015;   Arista Router;              12
# 5   12/12/2015;   Arista Router;               5
# 6   12/12/2015;   Arista Router;              11
# 7   12/12/2015;   Arista Router;               4
# 8   12/12/2015;   Arista Router;              20
# ...

# %%
 ab=df.groupby(df["Product Name;"])["Number Of Bugs"].sum() 
plt.pie(ab,labels=ab.index,autopct="%.f%%",); 
plt.show()
